# %% [markdown]
# # Live Demo — Week 3
#
# **Instructor copy.** This notebook was edited live during prep: an
# earlier version of the filter below used a different site, and this
# cell was never re-run after the edit. Scrolling through top to bottom,
# nothing looks wrong -- that's the point.

# %%
import pandas as pd

patients = pd.DataFrame({
    "patient_id": ["P001", "P002", "P003", "P004", "P005"],
    "age": [54, 61, 47, 72, 39],
    "site": ["DC", "MD", "DC", "VA", "MD"],
})

# %% [markdown]
# ## Average age, DC site patients

# %%
dc_patients = patients[patients["site"] == "DC"]
dc_patients["age"].mean()
# Out:
# 72.0
